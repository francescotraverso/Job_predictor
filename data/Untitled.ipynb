# %%
import pandas as pd
import requests

# %%
ls data/ESCO/
# Out:
# conceptSchemes_en.csv            occupations_en.csv
# digCompSkillsCollection_en.csv   researchSkillsCollection_en.csv
# greenSkillsCollection_en.csv     skillGroups_en.csv
# ictSkillsCollection_en.csv       skills_en.csv
# ISCOGroups_en.csv                skillsHierarchy_en.csv
# languageSkillsCollection_en.csv  transversalSkillsCollection_en.csv

# %%
df = pd.read_csv('data/ESCO/occupations_en.csv')

# %%
df
# Out:
#      conceptType                                         conceptUri  \
# 0     Occupation  http://data.europa.eu/esco/occupation/00030d09...
# 1     Occupation  http://data.europa.eu/esco/occupation/000e93a3...
# 2     Occupation  http://data.europa.eu/esco/occupation/0019b951...
# 3     Occupation  http://data.europa.eu/esco/occupation/0022f466...
# 4     Occupation  http://data.europa.eu/esco/occupation/002da35b...
# ...          ...                                                ...
# 3003  Occupation  http://data.europa.eu/esco/occupation/ff656b3a...
# 3004  Occupation  http://data.europa.eu/esco/occupation/ff8d4065...
# 3005  Occupation  http://data.europa.eu/esco/occupation/ffa4dd5d...
# 3006  Occupation  http://data.europa.eu/esco/occupation/ffade2f4...
# 3007  Occupation  http://data.europa.eu/esco/occupation/ffc292f1...
#
#       iscoGroup                        preferredLabel  \
# 0          2654                    technical director
# ...

# %%
df_11 = df[df['preferredLabel'] =='gas chromatographer']

# %%
df_11
# Out:
# Empty DataFrame
# Columns: [conceptType, conceptUri, iscoGroup, preferredLabel, altLabels, hiddenLabels, status, modifiedDate, regulatedProfessionNote, scopeNote, definition, inScheme, description, code]
# Index: []

# %%
df.loc[0][4]
# Out:
# 'technical and operations director\nhead of technical\ndirector of technical arts\nhead of technical department\ntechnical supervisor\ntechnical director\ntechnical manager'

# %%
df2 = pd.read_csv('data/ESCO/skills_en.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13891 entries, 0 to 13890
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   conceptType     13891 non-null  object
#  1   conceptUri      13891 non-null  object
#  2   skillType       13890 non-null  object
#  3   reuseLevel      13891 non-null  object
#  4   preferredLabel  13891 non-null  object
#  5   altLabels       13699 non-null  object
#  6   hiddenLabels    109 non-null    object
#  7   status          13891 non-null  object
#  8   modifiedDate    13891 non-null  object
#  9   scopeNote       226 non-null    object
#  10  definition      3 non-null      object
#  11  inScheme        13891 non-null  object
#  12  description     13891 non-null  object
# dtypes: object(13)
# memory usage: 1.4+ MB

# %%
df2.loc[0][-2]
# Out:
# 'http://data.europa.eu/esco/concept-scheme/skills,\nhttp://data.europa.eu/esco/concept-scheme/member-skills'

# %%
df3 = pd.read_csv('data/ESCO/skillGroups_en.csv')

# %%
df3
# Out:
#     conceptType                                         conceptUri  \
# 0    SkillGroup              http://data.europa.eu/esco/isced-f/00
# 1    SkillGroup             http://data.europa.eu/esco/isced-f/000
# 2    SkillGroup            http://data.europa.eu/esco/isced-f/0000
# 3    SkillGroup             http://data.europa.eu/esco/isced-f/001
# 4    SkillGroup            http://data.europa.eu/esco/isced-f/0011
# ..          ...                                                ...
# 638  SkillGroup              http://data.europa.eu/esco/skill/T6.3
# 639  SkillGroup              http://data.europa.eu/esco/skill/T6.4
# 640  SkillGroup              http://data.europa.eu/esco/skill/T6.5
# 641  SkillGroup              http://data.europa.eu/esco/skill/T6.6
# 642  SkillGroup  http://data.europa.eu/esco/skill/f5369f2f-e52b...
#
#                                         preferredLabel  \
# 0                generic programmes and qualifications
# ...

# %%
df4 = pd.read_csv('data/ESCO/researchSkillsCollection_en.csv')

# %%
df4
# Out:
#                  conceptType  \
# 0   KnowledgeSkillCompetence
# 1   KnowledgeSkillCompetence
# 2   KnowledgeSkillCompetence
# 3   KnowledgeSkillCompetence
# 4   KnowledgeSkillCompetence
# 5   KnowledgeSkillCompetence
# 6   KnowledgeSkillCompetence
# 7   KnowledgeSkillCompetence
# 8   KnowledgeSkillCompetence
# 9   KnowledgeSkillCompetence
# 10  KnowledgeSkillCompetence
# 11  KnowledgeSkillCompetence
# 12  KnowledgeSkillCompetence
# 13  KnowledgeSkillCompetence
# 14  KnowledgeSkillCompetence
# 15  KnowledgeSkillCompetence
# 16  KnowledgeSkillCompetence
# 17  KnowledgeSkillCompetence
# 18  KnowledgeSkillCompetence
# 19  KnowledgeSkillCompetence
# 20  KnowledgeSkillCompetence
# 21  KnowledgeSkillCompetence
# 22  KnowledgeSkillCompetence
# 23  KnowledgeSkillCompetence
# 24  KnowledgeSkillCompetence
# 25  KnowledgeSkillCompetence
# 26  KnowledgeSkillCompetence
# 27  KnowledgeSkillCompetence
# 28  KnowledgeSkillCompetence
# 29  KnowledgeSkillCompetence
# 30  KnowledgeSkillCompetence
# ...

# %%
df5 = pd.read_csv('data/ESCO/transversalSkillsCollection_en.csv')

# %%
df5
# Out:
#                  conceptType  \
# 0   KnowledgeSkillCompetence
# 1   KnowledgeSkillCompetence
# 2   KnowledgeSkillCompetence
# 3   KnowledgeSkillCompetence
# 4   KnowledgeSkillCompetence
# ..                       ...
# 91  KnowledgeSkillCompetence
# 92  KnowledgeSkillCompetence
# 93  KnowledgeSkillCompetence
# 94  KnowledgeSkillCompetence
# 95  KnowledgeSkillCompetence
#
#                                            conceptUri         skillType  \
# 0   http://data.europa.eu/esco/skill/001115fb-569f...  skill/competence
# 1   http://data.europa.eu/esco/skill/0171653e-c8e9...  skill/competence
# 2   http://data.europa.eu/esco/skill/045f71e6-0699...  skill/competence
# 3   http://data.europa.eu/esco/skill/05aa7c09-46e7...  skill/competence
# 4   http://data.europa.eu/esco/skill/0b709c64-a57a...  skill/competence
# ..                                                ...               ...
# 91  http://data.europa.eu/esco/skill/ef7562b2-f176...  skill/competence
# ...

# %%
url = "https://ec.europa.eu/esco/api/resource/skill"

params = {
    'uri': 'http://data.europa.eu/esco/occupation/8a87e8b3-aecf-48a7-9837-4e022c3b9bb9',
    'language': 'en',
         }

api_data = requests.get(url=url, params=params).url
api_data
# Out:
# 'https://ec.europa.eu/esco/api/resource/skill?uri=http%3A%2F%2Fdata.europa.eu%2Fesco%2Foccupation%2F8a87e8b3-aecf-48a7-9837-4e022c3b9bb9&language=en'

# %%
useful_info = api_data['title'],api_data['alternativeLabel']['en'],api_data['description']['en']
useful_info
# Out:
# ('chromatographer',
#  ['thin layer chromatographer',
#   'gas chromatographer',
#   'chromatography machine operative',
#   'ion-exchange chromatographer',
#   'liquid chromatographer',
#   'mass spectrometry specialist',
#   'LC-MS specialist',
#   'chromatography machine operator',
#   'mass spectrometry technician',
#   'gel permeation chromatographer',
#   'chromatography technician',
#   'high performance liquid chromatographer',
#   'chromatography machine technician'],
#  {'literal': "Chromatographers apply the corresponding chromatography techniques (such as gas, liquid or ion exchange techniques) to identify and analyse samples' chemical compounds. They calibrate and maintain the chromatography machinery and prepare the equipment and solutions. Chromatographers may also develop and apply new chromatography methods according to samples and chemical compounds that need to be analysed.",
#   'mimetype': 'plain/text'})

# %%
api_data['_links']['hasEssentialSkill']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 api_data['_links']['hasEssentialSkill']
#
# TypeError: string indices must be integers

# %%
type(api_data)
# Out:
# dict

# %%
import json

pd.read_json(json.dumps(api_data['alternativeLabel']['en']))
# Out:
#                                           0
# 0                thin layer chromatographer
# 1                       gas chromatographer
# 2          chromatography machine operative
# 3              ion-exchange chromatographer
# 4                    liquid chromatographer
# 5              mass spectrometry specialist
# 6                          LC-MS specialist
# 7           chromatography machine operator
# 8              mass spectrometry technician
# 9            gel permeation chromatographer
# 10                chromatography technician
# 11  high performance liquid chromatographer
# 12        chromatography machine technician

# %%
api_data['alternativeLabel']['en']
# Out:
# ['thin layer chromatographer',
#  'gas chromatographer',
#  'chromatography machine operative',
#  'ion-exchange chromatographer',
#  'liquid chromatographer',
#  'mass spectrometry specialist',
#  'LC-MS specialist',
#  'chromatography machine operator',
#  'mass spectrometry technician',
#  'gel permeation chromatographer',
#  'chromatography technician',
#  'high performance liquid chromatographer',
#  'chromatography machine technician']
